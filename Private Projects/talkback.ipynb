# %%
import torchaudio
import numpy
import matplotlib.pyplot as plt
import torch
from IPython.display import Audio


f = torchaudio.load("../../Desktop/Dittesstraße.m4a")
print(f[0].shape)
print(f[1])

plt.plot(f[0][0].numpy())
plt.show()


for i in range(len(f[0])):
    if i >= 0.3:
        i = 0
    else:
        i = i


Audio(f[0][0].numpy(), rate=f[1])
# Out:
# torch.Size([1, 139264])
# 44100
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
